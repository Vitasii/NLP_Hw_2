# %%
from dotenv import load_dotenv
import os

load_dotenv()  # 加载 .env 文件

# 现在可以直接使用
os.environ['WANDB_API_KEY'] = os.getenv('WANDB_API_KEY')
os.environ['WANDB_PROJECT'] = os.getenv('WANDB_PROJECT') 
os.environ['WANDB_NAME'] = 'TASK_2_1_1'
